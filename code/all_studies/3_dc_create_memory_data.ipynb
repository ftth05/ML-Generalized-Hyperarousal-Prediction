# %%
# %run us_common_functions.ipynb


combine_studies = True

# %%
# create_data = True


# files = [
#     'data_4',                    ### Single window - 10 sec - aggregation
#     ### 'data_4_scaled',         ### Single window - 10 sec - aggregation + standardized scale
    
#     'data_4_rolling',            ### Single rolling window - 10 sec - aggregation
#     ###'data_4_rolling_scaled',  ### Single rolling window - 10 sec - aggregation + standardized scale
    
    
    
#     'data_6',                    ### Multiple window data
#     ###'data_6_scaled',          ### Multiple window data + standardized scale
    
#     'data_6_rolling',            ### Multiple rolling window data
#     ###'data_6_rolling_scaled',  ### Multiple rolling window data + standardized scale
# ]

# %%
single_sec_df = pd.read_csv(all_studies_data_dir + 'data_2_5_study_combined.csv')
# single_sec_df = pd.read_csv(all_studies_data_dir + 'data_2_5_study_combined.csv').iloc[:1000]
single_sec_df.head(5)
# Out:
#    Unnamed: 0 Subject   Age  NASA_Effort  NASA_Frustration  NASA_Mental  \
# 0           0       2  23.0         17.0              11.0         18.0
# 1           1       2  23.0         17.0              11.0         18.0
# 2           2       2  23.0         17.0              11.0         18.0
# 3           3       2  23.0         17.0              11.0         18.0
# 4           4       2  23.0         17.0              11.0         18.0
#
#    NASA_Performance  NASA_Physical  NASA_Temporal  NASA_Total  TimeElapsed  \
# 0               8.0           12.0           11.0        77.0            5
# 1               8.0           12.0           11.0        77.0            6
# 2               8.0           12.0           11.0        77.0            7
# 3               8.0           12.0           11.0        77.0            8
# 4               8.0           12.0           11.0        77.0            9
#
#   Treatment  Gender  Perinasal  Perinasal_Log  Heart  Breathing  \
# 0        CD  Female   0.005414      -5.218846   90.2      10.80
# 1        CD  Female   0.005440      -5.214028   91.6      10.88
# 2        CD  Female   0.005449      -5.212386   92.2      10.92
# 3        CD  Female   0.005436      -5.214753   92.2      10.98
# 4        CD  Female   0.005403      -5.220885   91.6      11.02
#
#    PP_Normalized  HR_Normalized  BR_Normalized PP_Arousal HR_Arousal  \
# 0       0.035523       3.568182      -5.666682    relaxed   stressed
# 1       0.040341       4.968182      -5.586682    relaxed   stressed
# 2       0.041983       5.568182      -5.546682    relaxed   stressed
# 3       0.039616       5.568182      -5.486682    relaxed   stressed
# 4       0.033484       4.968182      -5.446682    relaxed   stressed
#
#   BR_Arousal   PP_ecdf   HR_ecdf   BR_ecdf  PP_HR_ecdf  PP_BR_ecdf  \
# 0    relaxed  0.429390  0.805745  0.082577    0.617568    0.255984
# 1    relaxed  0.449870  0.860445  0.084917    0.655158    0.267393
# 2    relaxed  0.456481  0.879747  0.086236    0.668114    0.271359
# 3    relaxed  0.446540  0.879747  0.088498    0.663144    0.267519
# 4    relaxed  0.420957  0.860445  0.089974    0.640701    0.255465
#
#    HR_BR_ecdf  PP_HR_BR_ecdf PP_Arousal_ecdf HR_Arousal_ecdf BR_Arousal_ecdf  \
# 0    0.444161       0.439237         neutral         arousal     non-arousal
# 1    0.472681       0.465077         neutral         arousal     non-arousal
# 2    0.482991       0.474155         neutral         arousal     non-arousal
# 3    0.484122       0.471595         neutral         arousal     non-arousal
# 4    0.475210       0.457125         neutral         arousal     non-arousal
#
#   PP_HR_Arousal_ecdf PP_BR_Arousal_ecdf HR_BR_Arousal_ecdf  \
# 0            neutral        non-arousal            neutral
# 1            neutral        non-arousal            neutral
# 2            neutral        non-arousal            neutral
# 3            neutral        non-arousal            neutral
# 4            neutral        non-arousal            neutral
#
#   PP_HR_BR_Arousal_ecdf Study_Name Study_Subject
# 0               neutral       sim1        sim1_2
# 1               neutral       sim1        sim1_2
# 2               neutral       sim1        sim1_2
# 3               neutral       sim1        sim1_2
# 4               neutral       sim1        sim1_2

# %%
single_sec_df.drop('Perinasal', axis=1, inplace=True)
single_sec_df.rename(columns = {'Perinasal_Log': 'Perinasal'}, inplace=True)
single_sec_df.head(5)
# Out:
#    Unnamed: 0 Subject   Age  NASA_Effort  NASA_Frustration  NASA_Mental  \
# 0           0       2  23.0         17.0              11.0         18.0
# 1           1       2  23.0         17.0              11.0         18.0
# 2           2       2  23.0         17.0              11.0         18.0
# 3           3       2  23.0         17.0              11.0         18.0
# 4           4       2  23.0         17.0              11.0         18.0
#
#    NASA_Performance  NASA_Physical  NASA_Temporal  NASA_Total  TimeElapsed  \
# 0               8.0           12.0           11.0        77.0            5
# 1               8.0           12.0           11.0        77.0            6
# 2               8.0           12.0           11.0        77.0            7
# 3               8.0           12.0           11.0        77.0            8
# 4               8.0           12.0           11.0        77.0            9
#
#   Treatment  Gender  Perinasal  Heart  Breathing  PP_Normalized  \
# 0        CD  Female  -5.218846   90.2      10.80       0.035523
# 1        CD  Female  -5.214028   91.6      10.88       0.040341
# 2        CD  Female  -5.212386   92.2      10.92       0.041983
# 3        CD  Female  -5.214753   92.2      10.98       0.039616
# 4        CD  Female  -5.220885   91.6      11.02       0.033484
#
#    HR_Normalized  BR_Normalized PP_Arousal HR_Arousal BR_Arousal   PP_ecdf  \
# 0       3.568182      -5.666682    relaxed   stressed    relaxed  0.429390
# 1       4.968182      -5.586682    relaxed   stressed    relaxed  0.449870
# 2       5.568182      -5.546682    relaxed   stressed    relaxed  0.456481
# 3       5.568182      -5.486682    relaxed   stressed    relaxed  0.446540
# 4       4.968182      -5.446682    relaxed   stressed    relaxed  0.420957
#
#     HR_ecdf   BR_ecdf  PP_HR_ecdf  PP_BR_ecdf  HR_BR_ecdf  PP_HR_BR_ecdf  \
# 0  0.805745  0.082577    0.617568    0.255984    0.444161       0.439237
# 1  0.860445  0.084917    0.655158    0.267393    0.472681       0.465077
# 2  0.879747  0.086236    0.668114    0.271359    0.482991       0.474155
# 3  0.879747  0.088498    0.663144    0.267519    0.484122       0.471595
# 4  0.860445  0.089974    0.640701    0.255465    0.475210       0.457125
#
#   PP_Arousal_ecdf HR_Arousal_ecdf BR_Arousal_ecdf PP_HR_Arousal_ecdf  \
# 0         neutral         arousal     non-arousal            neutral
# 1         neutral         arousal     non-arousal            neutral
# 2         neutral         arousal     non-arousal            neutral
# 3         neutral         arousal     non-arousal            neutral
# 4         neutral         arousal     non-arousal            neutral
#
#   PP_BR_Arousal_ecdf HR_BR_Arousal_ecdf PP_HR_BR_Arousal_ecdf Study_Name  \
# 0        non-arousal            neutral               neutral       sim1
# 1        non-arousal            neutral               neutral       sim1
# 2        non-arousal            neutral               neutral       sim1
# 3        non-arousal            neutral               neutral       sim1
# 4        non-arousal            neutral               neutral       sim1
#
#   Study_Subject
# 0        sim1_2
# 1        sim1_2
# 2        sim1_2
# 3        sim1_2
# 4        sim1_2

# %%
# %run us_common_functions.ipynb
# start_time = time.time()

# single_window_df = get_single_window_aggregrated_df(single_sec_df)
# single_window_df.to_csv(all_studies_data_dir + 'data_4.csv', sep=',', index=False)
# get_scaled_df(files=['data_4.csv'])


# ### BEWARE OF TIME TO RUN    
# single_rolling_window_df = get_single_window_aggregrated_df(single_sec_df, rolling_window=True)
# single_rolling_window_df.to_csv(all_studies_data_dir + 'data_4_rolling.csv', sep=',', index=False)
# get_scaled_df(files=['data_4_rolling.csv'])



# total_time = time.time() - start_time
# print("--- Total Time %s mins (%s hours) ---" % (total_time//60, total_time//3600))

# %%
# single_window_df = pd.read_csv(all_studies_data_dir + 'data_4.csv')
# single_rolling_window_df = pd.read_csv(all_studies_data_dir + 'data_4_rolling.csv')
    
# # print(single_window_df.Study_Name.unique())
# # print(single_window_df.Gender.unique())
# # print(single_window_df.Treatment.unique())

# %%
# %run us_common_functions.ipynb

# 15 - 30 - 60
train_w=60; test_w=10
start_time = time.time()



#############################################################################################
# rolling=False
# data_file_name = generate_file_name_with_window_info('data_6.csv', train_w, test_w, rolling) 
# multiple_window_df = get_multiple_window_aggregrated_df(single_sec_df.copy(), 
#                                        train_window_size=train_w, 
#                                        test_window_size=test_w, 
#                                        rolling_window=rolling)
# multiple_window_df.to_csv(all_studies_data_dir + data_file_name, sep=',', index=False)
# get_scaled_df(files=[data_file_name])
# multiple_rolling_window_df.head()

# total_time = time.time() - start_time
# print("--- Total Time for Non-Rolling Window %s mins (%s hours) ---" % (total_time//60, total_time//3600)) 
#############################################################################################



if combine_studies:
    #############################################################################################
    ### BEWARE OF TIME TO RUN
    rolling=True 
    data_file_name = generate_file_name_with_window_info('data_6.csv', train_w, test_w, rolling) 
    multiple_rolling_window_df = get_multiple_window_aggregrated_df(single_sec_df.copy(),
                                           train_window_size=train_w, 
                                           test_window_size=test_w, 
                                           rolling_window=True)
    multiple_rolling_window_df.to_csv(all_studies_data_dir + data_file_name, sep=',', index=False)
    get_scaled_df(files=[data_file_name])
    # multiple_rolling_window_df.head()


    total_time = time.time() - start_time
    print("--- Total Time for Rolling Window %s mins (%s hours) ---" % (total_time//60, total_time//3600))
    #############################################################################################
# Out:
# (1023091, 38)
# sim1 2
# sim1 3
# sim1 5
# sim1 8
# sim1 14
# sim1 16
# sim1 17
# sim1 18
# sim1 20
# sim1 23
# sim1 24
# sim1 25
# sim1 29
# sim1 31
# sim1 33
# sim1 36
# sim1 38
# sim1 39
# sim1 43
# sim1 44
# sim1 45
# sim1 47
# sim1 60
# sim1 61
# sim1 62
# sim1 66
# sim1 77
# sim1 79
# sim1 80
# sim1 81
# sim1 84
# sim2 23
# sim2 24
# sim2 25
# sim2 26
# sim2 27
# sim2 37
# sim2 38
# sim2 39
# sim2 40
# sim2 43
# sim2 45
# sim2 46
# sim2 47
# sim2 48
# sim2 49
# sim2 52
# sim2 53
# sim2 54
# sim2 56
# sim2 64
# sim2 65
# tt1 1
# tt1 2
# tt1 3
# tt1 4
# tt1 5
# tt1 6
# tt1 7
# tt1 9
# tt1 10
# tt1 13
# tt1 15
# tt1 16
# tt1 17
# tt1 22
# tt1 24
# tt1 26
# tt1 29
# tt1 30
# tt1 31
# tt1 32
# office_tasks 3
# office_tasks 11
# office_tasks 16
# office_tasks 19
# office_tasks 32
# office_tasks 46
# office_tasks 61
# office_tasks 63
# office_tasks 64
# office_tasks 65
# office_tasks 66
# office_tasks 68
# office_tasks 77
# office_tasks 79
# office_tasks 83
# office_tasks 84
# office_tasks 85
# office_tasks 91
# office_tasks 92
# office_tasks 93
# office_tasks 94
# office_tasks 98
# office_tasks 99
# office_tasks 106
# office_tasks 112
# office_tasks 114
# office_tasks 121
# office_tasks 122
# office_tasks 124
# office_tasks 128
# office_tasks 132
# office_tasks 138
# office_tasks 139
# office_tasks 141
# office_tasks 151
# office_tasks 152
# office_tasks 154
# office_tasks 156
# office_tasks 157
# office_tasks 166
# office_tasks 172
# office_tasks 173
# office_tasks 174
# office_tasks 175
# deadline_study 5
# deadline_study 7
# deadline_study 9
# deadline_study 11
# deadline_study 13
# deadline_study 15
# deadline_study 17

# %%
# data_files = ['data_6_rolling_w15_5.csv',
#               'data_6_rolling_w30_5.csv', 
#               'data_6_rolling_w30_10.csv',
#              ]


# for data_file in data_files:
#     df = pd.read_csv(all_studies_data_dir + data_file)
#     df = round_nasa(df)
#     get_scaled_df(files=[data_file])

# %%
# multiple_window_df = pd.read_csv(all_studies_data_dir + 'data_6.csv')
# multiple_rolling_window_df = pd.read_csv(all_studies_data_dir + 'data_7.csv')

# print(multiple_window_df.Gender.unique())
# print(multiple_window_df.Treatment.unique())
