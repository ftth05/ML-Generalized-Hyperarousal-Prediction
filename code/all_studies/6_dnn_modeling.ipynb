# %% [markdown]
# # LSTM - Generic Framework - Investigation

# %%
#####################################################################################
run_models = True
run_k_fold = False
overleaf_metrics = False
print_all = False
is_deadline = False
#####################################################################################


#####################################################################################
# ['DNN', 'LSTM']
model_name = 'LSTM'
#####################################################################################


#####################################################################################
k_fold_n_splits = 5
#####################################################################################



#####################################################################################
arousal_signals = ['PP']
# arousal_signals = ['PP', 'BR']
# arousal_signals = ['PP_HR_BR']
# arousal_signals = ['PP', 'HR', 'BR']
# arousal_signals = ['PP', 'HR', 'BR', 'PP_HR', 'HR_BR', 'PP_BR', 'PP_HR_BR']
#####################################################################################



#####################################################################################
# %run us_common_functions.ipynb
#####################################################################################




#####################################################################################
# study_combinations_to_run = list(study_combinations.keys())
# study_combinations_to_run = list(study_combinations.keys())[:4]
# study_combinations_to_run = list(study_combinations.keys())[4:]

# study_combinations_to_run = ['sim1', 'sim1___sim2___tt1___office_tasks']
# study_combinations_to_run = ['sim2', 'tt1', 'office_tasks', 'sim1___sim2', 'sim1___sim2___tt1']
# study_combinations_to_run = ['sim1___sim2___tt1___office_tasks']
# study_combinations_to_run = ['sim1', 'tt1']
# study_combinations_to_run = ['sim1']
#### study_combinations_to_run.remove(deadline_study)
####################################################################################




####################################################################################
### study_combinations_to_run = all_study_combinations[:-1]
### study_combinations_to_run = ['sim1___sim2___tt1___office_tasks']

study_combinations, all_study_combinations = get_study_combinations(studies)
study_combinations_to_run = all_study_combinations
print(study_combinations_to_run)
####################################################################################




# #####################################################################################
# # For Deadline Study - Without BR
# #####################################################################################
# studies.append(deadline_study)
# study_combinations, all_study_combinations = get_study_combinations(studies)
# study_combinations_to_run = studies
# print(study_combinations_to_run)

# arousal_signals = ['PP', 'HR', 'PP_HR']
# model_features.remove('BR_Mean')
# model_features.remove('BR_SD')

# is_deadline=True
# ####################################################################################










####################################################################################
# ground_truth_method = 'hist'
ground_truth_method = 'ecdf'
####################################################################################




####################################################################################
epochs = 2  # 10
batch_size = 32
verbose = 1
####################################################################################

# %%
####################################################################################
# Initialization
####################################################################################
model_metrics = {}
overleaf_final_tables = defaultdict(lambda : None)
study_combination_model_metrics = defaultdict(lambda : None)

# figure_path = all_studies_fig_dir
# plot_name = None



# data_6_rolling_w15_5_scaled.csv
# data_6_rolling_w30_5_scaled.csv
# data_6_rolling_w60_5_scaled.csv
dnn_data_file = 'data_6_rolling_w30_5_scaled.csv'

dnn_window_size = dnn_data_file[-15:-11]
####################################################################################

# %%
# all_studies_df = pd.read_csv(all_studies_data_dir + dnn_data_file)
all_studies_df = pd.read_csv(all_studies_data_dir + dnn_data_file).iloc[:2000,]
all_studies_df.rename({'Perinasal_Log_Window': 'Perinasal_Window'}, axis=1, inplace=True)
all_studies_df.shape
# Out:
# (2000, 58)

# %%
all_studies_df.head(2)
# Out:
#   Study_Name Subject Study_Subject Treatment       Age  NASA_Effort  \
# 0       sim1       2        sim1_2        CD -0.886388      0.96301
# 1       sim1       2        sim1_2        CD -0.886388      0.96301
#
#    NASA_Frustration  NASA_Mental  NASA_Performance  NASA_Physical  \
# 0          0.332856         18.0         -0.204407       0.548524
# 1          0.332856         18.0         -0.204407       0.548524
#
#    NASA_Temporal  NASA_Total  Perinasal_Mean_NN  Perinasal_Median_NN  \
# 0       0.367759        77.0          -5.282175            -5.297421
# 1       0.367759        77.0          -5.305937            -5.307565
#
#    Perinasal_SD_NN  Perinasal_SS_NN  \
# 0         0.037635       837.082385
# 1         0.033802       844.622019
#
#                                  Perinasal_Window_NN  Perinasal_Mean  \
# 0  -5.218846387983004, -5.214028019882206, -5.212...       -0.704197
# 1  -5.229819391933348, -5.24046285310951, -5.2518...       -0.864359
#
#    Perinasal_Median  Perinasal_SD  Perinasal_SS  \
# 0         -0.043052      0.102389      0.064272
# 1         -0.053195     -0.021171      0.112911
#
#                                     Perinasal_Window  Heart_Mean_NN  \
# 0  0.0355228579351853, 0.0403412260359834, 0.0419...      90.540000
# 1  0.0245498539848414, 0.0139063928086793, 0.0025...      89.553333
#
#    Heart_Median_NN  Heart_SD_NN  Heart_SS_NN  \
# 0             90.4     1.436615    245984.60
# 1             90.2     2.234330    240738.76
#
#                                      Heart_Window_NN   HR_Mean  HR_Median  \
# 0  90.2, 91.6, 92.2, 92.2, 91.6, 90.4, 89.2, 88.8...  0.919132   3.768182
# 1  90.4, 89.2, 88.8, 88.6, 88.6, 89.4, 90.2, 90.4...  0.698460   3.568182
#
#       HR_SD       HR_SS                                       Heart_Window  \
# 0 -0.513985  518.068554  3.5681818181818272, 4.968181818181819, 5.56818...
# 1  0.052955  400.832190  3.76818181818183, 2.5681818181818272, 2.168181...
#
#    Breathing_Mean_NN  Breathing_Median_NN  Breathing_SD_NN  Breathing_SS_NN  \
# 0          12.054667                 12.1         0.903494        4383.1224
# 1          12.553333                 12.5         0.965521        4754.6200
#
#                                  Breathing_Window_NN   BR_Mean  BR_Median  \
# 0  10.8, 10.88, 10.92, 10.98, 11.02, 11.08, 11.12... -1.088477  -4.366682
# 1  11.08, 11.12, 11.18, 11.22, 11.32, 11.4, 11.56... -0.948112  -3.966682
#
#       BR_SD       BR_SS                                   Breathing_Window  \
# 0  0.178627  607.649078  -5.666681818181818, -5.586681818181818, -5.546...
# 1  0.281929  486.463558  -5.386681818181819, -5.346681818181819, -5.286...
#
#   PP_Arousal_Mode_Hist HR_Arousal_Mode_Hist BR_Arousal_Mode_Hist  \
# 0              relaxed              relaxed              relaxed
# 1              relaxed             stressed              relaxed
#
#   PP_Arousal_Mode HR_Arousal_Mode BR_Arousal_Mode PP_HR_Arousal_Mode  \
# 0         relaxed         neutral         relaxed            relaxed
# 1         relaxed         neutral         relaxed            neutral
#
#   PP_BR_Arousal_Mode HR_BR_Arousal_Mode PP_HR_BR_Arousal_Mode    Gender  \
# 0            relaxed            neutral               relaxed  0.691472
# 1            relaxed            neutral               neutral  0.691472
#
#    Gender_Male PP_HR_Arousal_Mode_Hist PP_BR_Arousal_Mode_Hist  \
# 0            0                 relaxed                 relaxed
# 1            0                 relaxed                 relaxed
#
#   HR_BR_Arousal_Mode_Hist PP_HR_BR_Arousal_Mode_Hist
# 0                 relaxed                    relaxed
# 1                 relaxed                    relaxed

# %%
all_studies_df.columns
# Out:
# Index(['Study_Name', 'Subject', 'Study_Subject', 'Treatment', 'Age',
#        'NASA_Effort', 'NASA_Frustration', 'NASA_Mental', 'NASA_Performance',
#        'NASA_Physical', 'NASA_Temporal', 'NASA_Total', 'Perinasal_Mean',
#        'Perinasal_Median', 'Perinasal_SD', 'Perinasal_SS',
#        'Perinasal_Mean_10s', 'Perinasal_Median_10s', 'Perinasal_SD_10s',
#        'Perinasal_SS_10s', 'Perinasal_Window', 'HR_Mean', 'HR_Median', 'HR_SD',
#        'HR_SS', 'Heart_Mean_10s', 'Heart_Median_10s', 'Heart_SD_10s',
#        'Heart_SS_10s', 'Heart_Window', 'BR_Mean', 'BR_Median', 'BR_SD',
#        'BR_SS', 'Breathing_Mean_10s', 'Breathing_Median_10s',
#        'Breathing_SD_10s', 'Breathing_SS_10s', 'Breathing_Window',
#        'PP_Arousal_Mode_Hist', 'HR_Arousal_Mode_Hist', 'BR_Arousal_Mode_Hist',
#        'PP_Arousal_Mode', 'HR_Arousal_Mode', 'BR_Arousal_Mode',
#        'PP_HR_Arousal_Mode', 'PP_BR_Arousal_Mode', 'HR_BR_Arousal_Mode',
#        'PP_HR_BR_Arousal_Mode', 'Gender', 'Gender_Male',
#        'PP_HR_Arousal_Mode_Hist', 'PP_BR_Arousal_Mode_Hist',
#        'HR_BR_Arousal_Mode_Hist', 'PP_HR_BR_Arousal_Mode_Hist'],
#       dtype='object')

# %%
all_studies_df = process_ts_features(all_studies_df)
all_studies_df = create_categorical_labels(all_studies_df)

# %%
start_time = time.time()

# study_combinations_to_run
# all_study_combinations
for study_combination in study_combinations_to_run:   
    
    train_studies = study_combinations[study_combination]['Train']
    test_studies = study_combinations[study_combination]['Test']
    # print(train_studies, test_studies, study_combination)
    
    train_df = all_studies_df.copy()[all_studies_df.Study_Name.isin(train_studies)]
    # print(all_studies_df.shape, train_df.shape)
    
    model_metrics = {}

    
    for arousal_signal in arousal_signals:
        
        train_df = all_studies_df.copy()[all_studies_df.Study_Name.isin(train_studies)]
        # if ground_truth_method == 'ecdf': 
        # train_df = train_df[train_df[arousal_signal+'_Arousal_Mode_Cat'] != -1]
        
        try:
            print(decorator + '\n' + decorator)
            print('Train Studies: ', study_combination.upper() + ' & Modality: ' + arousal_signal)
            print(decorator + '\n' + decorator + '\n')


            # Ref: https://stackoverflow.com/questions/3975376/understanding-dict-copy-shallow-or-deep
            model_metrics[arousal_signal] = {
                'K_Fold': copy.deepcopy(all_metrics),
                'Train': copy.deepcopy(all_metrics),
                'Test': {}
            }

            # print(train_df[arousal_signal+'_Arousal_Mode_Cat'].unique())
            # print(train_df.shape)
            
            model = get_trained_dnn_model(train_df, arousal_signal)


            # for i, test_study in enumerate(test_studies):
            for j in range(1, len(test_studies)+1):
                for subset in itertools.combinations(test_studies, j):
              
                    test_study_subset = list(subset)
                    test_study_str = '___'.join(test_study_subset)
                    
                    if test_study_str in all_study_combinations:
                        # print('\n------------------------ Test Study' + str(i+1) + ': ' + test_study.upper() + ' ------------------------')
                        print('\n------------------------ Test Study: ' + test_study_str.upper() + ' ------------------------')

                        model_metrics[arousal_signal]['Test'][test_study_str.upper()] = copy.deepcopy(all_metrics)
                        # test_df = all_studies_df.copy()[all_studies_df.Study_Name.isin(test_study_subset)]
                        test_df = all_studies_df.copy()[all_studies_df.Study_Name == test_study_str]
                        # if ground_truth_method == 'ecdf': 
                        # test_df = test_df[test_df[arousal_signal+'_Arousal_Mode_Cat'] != -1]
                        test_dnn_model(model, test_study_str.upper(), test_df, arousal_signal)

                        metrics_df = metrics_df.append(get_test_study_metrics_df(arousal_signal, study_combination, test_study_str, model_metrics, k_fold=run_k_fold), ignore_index = True)

            if not test_studies: metrics_df = metrics_df.append(get_test_study_metrics_df(arousal_signal, study_combination, None, model_metrics, k_fold=False), ignore_index = True)
    
        except Exception as e:
            print("An exception occurred for %s %s --> %s" % (study_combination, arousal_signal, e))
    
    # pprint.pprint(model_metrics)
    # overleaf_final_tables[study_combination] = get_overleaf_table(study_combination, model_metrics)
    study_combination_model_metrics[study_combination] = model_metrics
    
    
display(metrics_df)
metrics_file_name = 'dnn_deadline_____' if is_deadline else 'dnn_____'
metrics_df.to_csv(add_path(all_studies_data_dir, metrics_dir) + metrics_file_name + dnn_window_size + '_v4_' + get_date_time() + '.csv', sep=',', index=False)


end_time = time.time()
# Out:
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: PP
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 204/204 [==============================] - 13s 27ms/step - loss: 1.5189 - accuracy: 0.6963 - auc_63: 0.8807 - f1_m: 0.5606 - precision_m: 0.8507 - recall_m: 0.4407 - val_loss: 0.0540 - val_accuracy: 0.7964 - val_auc_63: 0.9442 - val_f1_m: 0.7387 - val_precision_m: 0.9420 - val_recall_m: 0.6154
# Epoch 2/10
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0413 - accuracy: 0.8396 - auc_63: 0.9518 - f1_m: 0.8134 - precision_m: 0.9539 - recall_m: 0.7198 - val_loss: 0.0355 - val_accuracy: 0.8930 - val_auc_63: 0.9653 - val_f1_m: 0.8831 - val_precision_m: 0.9355 - val_recall_m: 0.8419
# Epoch 3/10
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0318 - accuracy: 0.8770 - auc_63: 0.9669 - f1_m: 0.8626 - precision_m: 0.9677 - recall_m: 0.7863 - val_loss: 0.0284 - val_accuracy: 0.8942 - val_auc_63: 0.9763 - val_f1_m: 0.8790 - val_precision_m: 0.9755 - val_recall_m: 0.8070
# Epoch 4/10
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0278 - accuracy: 0.8910 - auc_63: 0.9740 - f1_m: 0.8781 - precision_m: 0.9684 - recall_m: 0.8115 - val_loss: 0.0260 - val_accuracy: 0.9114 - val_auc_63: 0.9789 - val_f1_m: 0.8993 - val_precision_m: 0.9757 - val_recall_m: 0.8406
# Epoch 5/10
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0260 - accuracy: 0.8971 - auc_63: 0.9756 - f1_m: 0.8850 - precision_m: 0.9725 - recall_m: 0.8193 - val_loss: 0.0249 - val_accuracy: 0.9200 - val_auc_63: 0.9797 - val_f1_m: 0.9098 - val_precision_m: 0.9700 - val_recall_m: 0.8622
# Epoch 6/10
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0245 - accuracy: 0.9053 - auc_63: 0.9780 - f1_m: 0.8951 - precision_m: 0.9758 - recall_m: 0.8342 - val_loss: 0.0236 - val_accuracy: 0.8918 - val_auc_63: 0.9831 - val_f1_m: 0.8755 - val_precision_m: 0.9856 - val_recall_m: 0.7928
# Epoch 7/10
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0227 - accuracy: 0.9096 - auc_63: 0.9811 - f1_m: 0.8985 - precision_m: 0.9715 - recall_m: 0.8414 - val_loss: 0.0238 - val_accuracy: 0.9022 - val_auc_63: 0.9805 - val_f1_m: 0.8903 - val_precision_m: 0.9815 - val_recall_m: 0.8220
# Epoch 8/10
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0215 - accuracy: 0.9153 - auc_63: 0.9825 - f1_m: 0.9087 - precision_m: 0.9758 - recall_m: 0.8554 - val_loss: 0.0238 - val_accuracy: 0.9139 - val_auc_63: 0.9807 - val_f1_m: 0.9048 - val_precision_m: 0.9695 - val_recall_m: 0.8548
# Epoch 9/10
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0211 - accuracy: 0.9167 - auc_63: 0.9825 - f1_m: 0.9049 - precision_m: 0.9797 - recall_m: 0.8469 - val_loss: 0.0216 - val_accuracy: 0.9157 - val_auc_63: 0.9831 - val_f1_m: 0.9059 - val_precision_m: 0.9760 - val_recall_m: 0.8504
# Epoch 10/10
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0204 - accuracy: 0.9208 - auc_63: 0.9840 - f1_m: 0.9128 - precision_m: 0.9816 - recall_m: 0.8594 - val_loss: 0.0214 - val_accuracy: 0.9367 - val_auc_63: 0.9852 - val_f1_m: 0.9324 - val_precision_m: 0.9701 - val_recall_m: 0.9021
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 4088, 0: 4042})
#
# Validation Data - True -->
# Counter({0: 831, 1: 795})
#
# Validation Data - Prediction -->
# Counter({0: 888, 1: 738})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 1321, 0: 1209})
#
# Test Data - Prediction -->
# Counter({0: 1299, 1: 1231})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({0: 563, 1: 553})
#
# Test Data - Prediction -->
# Counter({0: 661, 1: 455})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 8610, 0: 8354})
#
# Test Data - Prediction -->
# Counter({0: 8889, 1: 8075})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15116, 0: 14682})
#
# Test Data - Prediction -->
# Counter({1: 16820, 0: 12978})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: HR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 205/205 [==============================] - 19s 24ms/step - loss: 1.5146 - accuracy: 0.6389 - auc_64: 0.8333 - f1_m: 0.4132 - precision_m: 0.7954 - recall_m: 0.2979 - val_loss: 0.0637 - val_accuracy: 0.7755 - val_auc_64: 0.8978 - val_f1_m: 0.7339 - val_precision_m: 0.9042 - val_recall_m: 0.6280
# Epoch 2/10
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0505 - accuracy: 0.7557 - auc_64: 0.9033 - f1_m: 0.6787 - precision_m: 0.9453 - recall_m: 0.5455 - val_loss: 0.0466 - val_accuracy: 0.8135 - val_auc_64: 0.9191 - val_f1_m: 0.7919 - val_precision_m: 0.9064 - val_recall_m: 0.7109
# Epoch 3/10
# 205/205 [==============================] - 2s 9ms/step - loss: 0.0424 - accuracy: 0.8024 - auc_64: 0.9225 - f1_m: 0.7554 - precision_m: 0.9500 - recall_m: 0.6378 - val_loss: 0.0413 - val_accuracy: 0.8043 - val_auc_64: 0.9228 - val_f1_m: 0.7647 - val_precision_m: 0.9520 - val_recall_m: 0.6480
# Epoch 4/10
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0396 - accuracy: 0.8097 - auc_64: 0.9309 - f1_m: 0.7659 - precision_m: 0.9525 - recall_m: 0.6511 - val_loss: 0.0387 - val_accuracy: 0.8122 - val_auc_64: 0.9323 - val_f1_m: 0.7796 - val_precision_m: 0.9456 - val_recall_m: 0.6711
# Epoch 5/10
# 205/205 [==============================] - 2s 12ms/step - loss: 0.0366 - accuracy: 0.8158 - auc_64: 0.9391 - f1_m: 0.7756 - precision_m: 0.9547 - recall_m: 0.6642 - val_loss: 0.0366 - val_accuracy: 0.8220 - val_auc_64: 0.9400 - val_f1_m: 0.7905 - val_precision_m: 0.9420 - val_recall_m: 0.6932
# Epoch 6/10
# 205/205 [==============================] - 2s 11ms/step - loss: 0.0354 - accuracy: 0.8273 - auc_64: 0.9404 - f1_m: 0.7937 - precision_m: 0.9580 - recall_m: 0.6865 - val_loss: 0.0363 - val_accuracy: 0.8281 - val_auc_64: 0.9395 - val_f1_m: 0.8019 - val_precision_m: 0.9402 - val_recall_m: 0.7069
# Epoch 7/10
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0344 - accuracy: 0.8267 - auc_64: 0.9442 - f1_m: 0.7901 - precision_m: 0.9548 - recall_m: 0.6857 - val_loss: 0.0363 - val_accuracy: 0.8312 - val_auc_64: 0.9400 - val_f1_m: 0.8101 - val_precision_m: 0.9177 - val_recall_m: 0.7324
# Epoch 8/10
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0327 - accuracy: 0.8350 - auc_64: 0.9487 - f1_m: 0.8011 - precision_m: 0.9629 - recall_m: 0.6968 - val_loss: 0.0347 - val_accuracy: 0.8422 - val_auc_64: 0.9438 - val_f1_m: 0.8207 - val_precision_m: 0.9422 - val_recall_m: 0.7351
# Epoch 9/10
# 205/205 [==============================] - 2s 10ms/step - loss: 0.0321 - accuracy: 0.8408 - auc_64: 0.9493 - f1_m: 0.8106 - precision_m: 0.9667 - recall_m: 0.7076 - val_loss: 0.0353 - val_accuracy: 0.8269 - val_auc_64: 0.9399 - val_f1_m: 0.8003 - val_precision_m: 0.9446 - val_recall_m: 0.7041
# Epoch 10/10
# 205/205 [==============================] - 2s 9ms/step - loss: 0.0316 - accuracy: 0.8400 - auc_64: 0.9513 - f1_m: 0.8089 - precision_m: 0.9619 - recall_m: 0.7069 - val_loss: 0.0348 - val_accuracy: 0.8220 - val_auc_64: 0.9423 - val_f1_m: 0.7943 - val_precision_m: 0.9342 - val_recall_m: 0.6988
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 4097, 0: 4076})
#
# Validation Data - True -->
# Counter({1: 829, 0: 806})
#
# Validation Data - Prediction -->
# Counter({0: 1019, 1: 616})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 1279, 0: 1223})
#
# Test Data - Prediction -->
# Counter({0: 1621, 1: 881})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({0: 581, 1: 566})
#
# Test Data - Prediction -->
# Counter({0: 789, 1: 358})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 8488, 0: 8428})
#
# Test Data - Prediction -->
# Counter({0: 10971, 1: 5945})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15089, 0: 14688})
#
# Test Data - Prediction -->
# Counter({0: 20047, 1: 9730})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 203/203 [==============================] - 12s 19ms/step - loss: 1.5102 - accuracy: 0.7577 - auc_65: 0.9110 - f1_m: 0.6653 - precision_m: 0.8599 - recall_m: 0.5675 - val_loss: 0.0500 - val_accuracy: 0.8176 - val_auc_65: 0.9505 - val_f1_m: 0.7929 - val_precision_m: 0.9607 - val_recall_m: 0.6857
# Epoch 2/10
# 203/203 [==============================] - 2s 9ms/step - loss: 0.0369 - accuracy: 0.8583 - auc_65: 0.9621 - f1_m: 0.8387 - precision_m: 0.9642 - recall_m: 0.7509 - val_loss: 0.0339 - val_accuracy: 0.8262 - val_auc_65: 0.9658 - val_f1_m: 0.8008 - val_precision_m: 0.9781 - val_recall_m: 0.6864
# Epoch 3/10
# 203/203 [==============================] - 2s 10ms/step - loss: 0.0287 - accuracy: 0.8815 - auc_65: 0.9739 - f1_m: 0.8672 - precision_m: 0.9648 - recall_m: 0.7949 - val_loss: 0.0277 - val_accuracy: 0.8675 - val_auc_65: 0.9748 - val_f1_m: 0.8535 - val_precision_m: 0.9767 - val_recall_m: 0.7664
# Epoch 4/10
# 203/203 [==============================] - 2s 11ms/step - loss: 0.0247 - accuracy: 0.8970 - auc_65: 0.9804 - f1_m: 0.8887 - precision_m: 0.9696 - recall_m: 0.8265 - val_loss: 0.0258 - val_accuracy: 0.8922 - val_auc_65: 0.9765 - val_f1_m: 0.8839 - val_precision_m: 0.9708 - val_recall_m: 0.8200
# Epoch 5/10
# 203/203 [==============================] - 2s 10ms/step - loss: 0.0218 - accuracy: 0.9120 - auc_65: 0.9846 - f1_m: 0.9034 - precision_m: 0.9784 - recall_m: 0.8456 - val_loss: 0.0243 - val_accuracy: 0.9119 - val_auc_65: 0.9791 - val_f1_m: 0.9069 - val_precision_m: 0.9620 - val_recall_m: 0.8662
# Epoch 6/10
# 203/203 [==============================] - 2s 10ms/step - loss: 0.0200 - accuracy: 0.9187 - auc_65: 0.9868 - f1_m: 0.9133 - precision_m: 0.9795 - recall_m: 0.8602 - val_loss: 0.0220 - val_accuracy: 0.9113 - val_auc_65: 0.9828 - val_f1_m: 0.9079 - val_precision_m: 0.9658 - val_recall_m: 0.8629
# Epoch 7/10
# 203/203 [==============================] - 2s 11ms/step - loss: 0.0187 - accuracy: 0.9259 - auc_65: 0.9885 - f1_m: 0.9200 - precision_m: 0.9795 - recall_m: 0.8734 - val_loss: 0.0205 - val_accuracy: 0.9156 - val_auc_65: 0.9841 - val_f1_m: 0.9125 - val_precision_m: 0.9811 - val_recall_m: 0.8576
# Epoch 8/10
# 203/203 [==============================] - 2s 11ms/step - loss: 0.0186 - accuracy: 0.9281 - auc_65: 0.9885 - f1_m: 0.9233 - precision_m: 0.9807 - recall_m: 0.8766 - val_loss: 0.0205 - val_accuracy: 0.9174 - val_auc_65: 0.9840 - val_f1_m: 0.9126 - val_precision_m: 0.9766 - val_recall_m: 0.8635
# Epoch 9/10
# 203/203 [==============================] - 3s 13ms/step - loss: 0.0166 - accuracy: 0.9356 - auc_65: 0.9910 - f1_m: 0.9320 - precision_m: 0.9828 - recall_m: 0.8900 - val_loss: 0.0199 - val_accuracy: 0.9137 - val_auc_65: 0.9851 - val_f1_m: 0.9104 - val_precision_m: 0.9678 - val_recall_m: 0.8659
# Epoch 10/10
# 203/203 [==============================] - 2s 12ms/step - loss: 0.0168 - accuracy: 0.9299 - auc_65: 0.9903 - f1_m: 0.9265 - precision_m: 0.9804 - recall_m: 0.8829 - val_loss: 0.0195 - val_accuracy: 0.9322 - val_auc_65: 0.9872 - val_f1_m: 0.9327 - val_precision_m: 0.9647 - val_recall_m: 0.9069
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 4191, 0: 3924})
#
# Validation Data - True -->
# Counter({1: 865, 0: 758})
#
# Validation Data - Prediction -->
# Counter({1: 815, 0: 808})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 1274, 0: 1261})
#
# Test Data - Prediction -->
# Counter({1: 1347, 0: 1188})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({1: 604, 0: 520})
#
# Test Data - Prediction -->
# Counter({1: 597, 0: 527})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 8624, 0: 8295})
#
# Test Data - Prediction -->
# Counter({0: 8943, 1: 7976})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15089, 0: 14688})
#
# Test Data - Prediction -->
# Counter({0: 15284, 1: 14493})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: PP_HR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 156/156 [==============================] - 16s 29ms/step - loss: 1.9733 - accuracy: 0.6675 - auc_66: 0.8515 - f1_m: 0.5008 - precision_m: 0.8327 - recall_m: 0.3806 - val_loss: 0.0952 - val_accuracy: 0.7583 - val_auc_66: 0.8919 - val_f1_m: 0.6639 - val_precision_m: 0.9386 - val_recall_m: 0.5327
# Epoch 2/10
# 156/156 [==============================] - 2s 11ms/step - loss: 0.0546 - accuracy: 0.8015 - auc_66: 0.9346 - f1_m: 0.7586 - precision_m: 0.9638 - recall_m: 0.6376 - val_loss: 0.0440 - val_accuracy: 0.8203 - val_auc_66: 0.9353 - val_f1_m: 0.7727 - val_precision_m: 0.9504 - val_recall_m: 0.6649
# Epoch 3/10
# 156/156 [==============================] - 2s 12ms/step - loss: 0.0368 - accuracy: 0.8505 - auc_66: 0.9598 - f1_m: 0.8267 - precision_m: 0.9708 - recall_m: 0.7310 - val_loss: 0.0386 - val_accuracy: 0.8517 - val_auc_66: 0.9486 - val_f1_m: 0.8279 - val_precision_m: 0.9259 - val_recall_m: 0.7578
# Epoch 4/10
# 156/156 [==============================] - 2s 11ms/step - loss: 0.0318 - accuracy: 0.8763 - auc_66: 0.9683 - f1_m: 0.8610 - precision_m: 0.9696 - recall_m: 0.7819 - val_loss: 0.0335 - val_accuracy: 0.8316 - val_auc_66: 0.9619 - val_f1_m: 0.7879 - val_precision_m: 0.9793 - val_recall_m: 0.6689
# Epoch 5/10
# 156/156 [==============================] - 3s 18ms/step - loss: 0.0295 - accuracy: 0.8809 - auc_66: 0.9721 - f1_m: 0.8594 - precision_m: 0.9644 - recall_m: 0.7835 - val_loss: 0.0303 - val_accuracy: 0.8598 - val_auc_66: 0.9686 - val_f1_m: 0.8275 - val_precision_m: 0.9847 - val_recall_m: 0.7242
# Epoch 6/10
# 156/156 [==============================] - 2s 13ms/step - loss: 0.0267 - accuracy: 0.8936 - auc_66: 0.9775 - f1_m: 0.8824 - precision_m: 0.9750 - recall_m: 0.8117 - val_loss: 0.0297 - val_accuracy: 0.8654 - val_auc_66: 0.9686 - val_f1_m: 0.8392 - val_precision_m: 0.9674 - val_recall_m: 0.7515
# Epoch 7/10
# 156/156 [==============================] - 2s 11ms/step - loss: 0.0251 - accuracy: 0.8962 - auc_66: 0.9797 - f1_m: 0.8852 - precision_m: 0.9754 - recall_m: 0.8170 - val_loss: 0.0280 - val_accuracy: 0.8727 - val_auc_66: 0.9732 - val_f1_m: 0.8504 - val_precision_m: 0.9745 - val_recall_m: 0.7609
# Epoch 8/10
# 156/156 [==============================] - 2s 10ms/step - loss: 0.0239 - accuracy: 0.9073 - auc_66: 0.9813 - f1_m: 0.8930 - precision_m: 0.9685 - recall_m: 0.8352 - val_loss: 0.0276 - val_accuracy: 0.8872 - val_auc_66: 0.9702 - val_f1_m: 0.8697 - val_precision_m: 0.9682 - val_recall_m: 0.7952
# Epoch 9/10
# 156/156 [==============================] - 2s 11ms/step - loss: 0.0224 - accuracy: 0.9079 - auc_66: 0.9840 - f1_m: 0.8999 - precision_m: 0.9776 - recall_m: 0.8389 - val_loss: 0.0277 - val_accuracy: 0.8848 - val_auc_66: 0.9716 - val_f1_m: 0.8668 - val_precision_m: 0.9652 - val_recall_m: 0.7931
# Epoch 10/10
# 156/156 [==============================] - 2s 10ms/step - loss: 0.0213 - accuracy: 0.9135 - auc_66: 0.9856 - f1_m: 0.9062 - precision_m: 0.9800 - recall_m: 0.8490 - val_loss: 0.0272 - val_accuracy: 0.8832 - val_auc_66: 0.9700 - val_f1_m: 0.8633 - val_precision_m: 0.9607 - val_recall_m: 0.7912
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 3123, 0: 3080})
#
# Validation Data - True -->
# Counter({0: 642, 1: 599})
#
# Validation Data - Prediction -->
# Counter({0: 747, 1: 494})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 900, 0: 861})
#
# Test Data - Prediction -->
# Counter({0: 1140, 1: 621})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({0: 404, 1: 403})
#
# Test Data - Prediction -->
# Counter({0: 510, 1: 297})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 6562, 0: 6141})
#
# Test Data - Prediction -->
# Counter({0: 7850, 1: 4853})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 10746, 1: 10642})
#
# Test Data - Prediction -->
# Counter({0: 13329, 1: 8059})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: HR_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 157/157 [==============================] - 12s 21ms/step - loss: 1.9314 - accuracy: 0.7918 - auc_67: 0.9299 - f1_m: 0.7155 - precision_m: 0.8941 - recall_m: 0.6198 - val_loss: 0.0773 - val_accuracy: 0.8494 - val_auc_67: 0.9665 - val_f1_m: 0.8323 - val_precision_m: 0.9841 - val_recall_m: 0.7282
# Epoch 2/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.0438 - accuracy: 0.8799 - auc_67: 0.9673 - f1_m: 0.8646 - precision_m: 0.9711 - recall_m: 0.7887 - val_loss: 0.0312 - val_accuracy: 0.8916 - val_auc_67: 0.9774 - val_f1_m: 0.8861 - val_precision_m: 0.9782 - val_recall_m: 0.8133
# Epoch 3/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.0288 - accuracy: 0.9020 - auc_67: 0.9792 - f1_m: 0.8919 - precision_m: 0.9780 - recall_m: 0.8249 - val_loss: 0.0268 - val_accuracy: 0.8948 - val_auc_67: 0.9823 - val_f1_m: 0.8895 - val_precision_m: 0.9829 - val_recall_m: 0.8165
# Epoch 4/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0254 - accuracy: 0.9131 - auc_67: 0.9824 - f1_m: 0.9037 - precision_m: 0.9799 - recall_m: 0.8452 - val_loss: 0.0239 - val_accuracy: 0.9259 - val_auc_67: 0.9861 - val_f1_m: 0.9240 - val_precision_m: 0.9802 - val_recall_m: 0.8777
# Epoch 5/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.0226 - accuracy: 0.9249 - auc_67: 0.9858 - f1_m: 0.9179 - precision_m: 0.9845 - recall_m: 0.8646 - val_loss: 0.0216 - val_accuracy: 0.9315 - val_auc_67: 0.9874 - val_f1_m: 0.9302 - val_precision_m: 0.9758 - val_recall_m: 0.8911
# Epoch 6/10
# 157/157 [==============================] - 1s 10ms/step - loss: 0.0206 - accuracy: 0.9255 - auc_67: 0.9883 - f1_m: 0.9191 - precision_m: 0.9813 - recall_m: 0.8696 - val_loss: 0.0245 - val_accuracy: 0.8932 - val_auc_67: 0.9822 - val_f1_m: 0.8883 - val_precision_m: 0.9834 - val_recall_m: 0.8144
# Epoch 7/10
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0203 - accuracy: 0.9247 - auc_67: 0.9877 - f1_m: 0.9172 - precision_m: 0.9788 - recall_m: 0.8680 - val_loss: 0.0193 - val_accuracy: 0.9291 - val_auc_67: 0.9896 - val_f1_m: 0.9266 - val_precision_m: 0.9797 - val_recall_m: 0.8813
# Epoch 8/10
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0187 - accuracy: 0.9291 - auc_67: 0.9899 - f1_m: 0.9235 - precision_m: 0.9814 - recall_m: 0.8769 - val_loss: 0.0203 - val_accuracy: 0.9315 - val_auc_67: 0.9876 - val_f1_m: 0.9308 - val_precision_m: 0.9744 - val_recall_m: 0.8934
# Epoch 9/10
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0175 - accuracy: 0.9354 - auc_67: 0.9907 - f1_m: 0.9311 - precision_m: 0.9824 - recall_m: 0.8895 - val_loss: 0.0199 - val_accuracy: 0.9355 - val_auc_67: 0.9879 - val_f1_m: 0.9361 - val_precision_m: 0.9747 - val_recall_m: 0.9031
# Epoch 10/10
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0173 - accuracy: 0.9364 - auc_67: 0.9909 - f1_m: 0.9326 - precision_m: 0.9828 - recall_m: 0.8923 - val_loss: 0.0184 - val_accuracy: 0.9227 - val_auc_67: 0.9904 - val_f1_m: 0.9193 - val_precision_m: 0.9794 - val_recall_m: 0.8684
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 3203, 0: 3071})
#
# Validation Data - True -->
# Counter({1: 657, 0: 598})
#
# Validation Data - Prediction -->
# Counter({0: 671, 1: 584})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 998, 0: 960})
#
# Test Data - Prediction -->
# Counter({0: 1055, 1: 903})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({1: 384, 0: 328})
#
# Test Data - Prediction -->
# Counter({0: 398, 1: 314})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 5957, 0: 5756})
#
# Test Data - Prediction -->
# Counter({0: 7040, 1: 4673})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15089, 0: 14688})
#
# Test Data - Prediction -->
# Counter({0: 20968, 1: 8809})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: PP_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 141/141 [==============================] - 13s 26ms/step - loss: 2.1494 - accuracy: 0.7720 - auc_68: 0.9196 - f1_m: 0.6988 - precision_m: 0.9187 - recall_m: 0.5942 - val_loss: 0.1101 - val_accuracy: 0.8729 - val_auc_68: 0.9621 - val_f1_m: 0.8555 - val_precision_m: 0.9716 - val_recall_m: 0.7727
# Epoch 2/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0506 - accuracy: 0.8788 - auc_68: 0.9715 - f1_m: 0.8647 - precision_m: 0.9722 - recall_m: 0.7854 - val_loss: 0.0315 - val_accuracy: 0.8907 - val_auc_68: 0.9825 - val_f1_m: 0.8788 - val_precision_m: 0.9791 - val_recall_m: 0.8019
# Epoch 3/10
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0277 - accuracy: 0.9181 - auc_68: 0.9838 - f1_m: 0.9121 - precision_m: 0.9816 - recall_m: 0.8572 - val_loss: 0.0238 - val_accuracy: 0.9280 - val_auc_68: 0.9899 - val_f1_m: 0.9215 - val_precision_m: 0.9791 - val_recall_m: 0.8735
# Epoch 4/10
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0222 - accuracy: 0.9319 - auc_68: 0.9898 - f1_m: 0.9270 - precision_m: 0.9838 - recall_m: 0.8806 - val_loss: 0.0213 - val_accuracy: 0.9307 - val_auc_68: 0.9909 - val_f1_m: 0.9265 - val_precision_m: 0.9782 - val_recall_m: 0.8857
# Epoch 5/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0186 - accuracy: 0.9462 - auc_68: 0.9933 - f1_m: 0.9423 - precision_m: 0.9894 - recall_m: 0.9027 - val_loss: 0.0194 - val_accuracy: 0.9342 - val_auc_68: 0.9927 - val_f1_m: 0.9309 - val_precision_m: 0.9843 - val_recall_m: 0.8870
# Epoch 6/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0168 - accuracy: 0.9506 - auc_68: 0.9945 - f1_m: 0.9478 - precision_m: 0.9880 - recall_m: 0.9146 - val_loss: 0.0190 - val_accuracy: 0.9191 - val_auc_68: 0.9937 - val_f1_m: 0.9128 - val_precision_m: 0.9883 - val_recall_m: 0.8555
# Epoch 7/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0150 - accuracy: 0.9622 - auc_68: 0.9955 - f1_m: 0.9613 - precision_m: 0.9901 - recall_m: 0.9362 - val_loss: 0.0161 - val_accuracy: 0.9378 - val_auc_68: 0.9957 - val_f1_m: 0.9350 - val_precision_m: 0.9887 - val_recall_m: 0.8907
# Epoch 8/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0134 - accuracy: 0.9620 - auc_68: 0.9968 - f1_m: 0.9601 - precision_m: 0.9910 - recall_m: 0.9336 - val_loss: 0.0149 - val_accuracy: 0.9387 - val_auc_68: 0.9969 - val_f1_m: 0.9360 - val_precision_m: 0.9914 - val_recall_m: 0.8899
# Epoch 9/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0126 - accuracy: 0.9695 - auc_68: 0.9967 - f1_m: 0.9681 - precision_m: 0.9945 - recall_m: 0.9452 - val_loss: 0.0147 - val_accuracy: 0.9680 - val_auc_68: 0.9958 - val_f1_m: 0.9684 - val_precision_m: 0.9838 - val_recall_m: 0.9566
# Epoch 10/10
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0115 - accuracy: 0.9693 - auc_68: 0.9976 - f1_m: 0.9680 - precision_m: 0.9923 - recall_m: 0.9469 - val_loss: 0.0133 - val_accuracy: 0.9582 - val_auc_68: 0.9964 - val_f1_m: 0.9571 - val_precision_m: 0.9859 - val_recall_m: 0.9320
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 2858, 0: 2763})
#
# Validation Data - True -->
# Counter({1: 579, 0: 546})
#
# Validation Data - Prediction -->
# Counter({0: 579, 1: 546})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 839, 0: 786})
#
# Test Data - Prediction -->
# Counter({1: 890, 0: 735})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({1: 335, 0: 297})
#
# Test Data - Prediction -->
# Counter({0: 352, 1: 280})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 5826, 0: 5279})
#
# Test Data - Prediction -->
# Counter({0: 5637, 1: 5468})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 10746, 1: 10642})
#
# Test Data - Prediction -->
# Counter({0: 11225, 1: 10163})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1 & Modality: PP_HR_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 127/127 [==============================] - 13s 28ms/step - loss: 2.3793 - accuracy: 0.7395 - auc_69: 0.8978 - f1_m: 0.6166 - precision_m: 0.8423 - recall_m: 0.5176 - val_loss: 0.1586 - val_accuracy: 0.8375 - val_auc_69: 0.9439 - val_f1_m: 0.8149 - val_precision_m: 0.9244 - val_recall_m: 0.7377
# Epoch 2/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0641 - accuracy: 0.8711 - auc_69: 0.9645 - f1_m: 0.8453 - precision_m: 0.9588 - recall_m: 0.7637 - val_loss: 0.0375 - val_accuracy: 0.8682 - val_auc_69: 0.9683 - val_f1_m: 0.8467 - val_precision_m: 0.9504 - val_recall_m: 0.7700
# Epoch 3/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0303 - accuracy: 0.9026 - auc_69: 0.9799 - f1_m: 0.8842 - precision_m: 0.9671 - recall_m: 0.8213 - val_loss: 0.0305 - val_accuracy: 0.9227 - val_auc_69: 0.9778 - val_f1_m: 0.9177 - val_precision_m: 0.9493 - val_recall_m: 0.8931
# Epoch 4/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0246 - accuracy: 0.9219 - auc_69: 0.9866 - f1_m: 0.9152 - precision_m: 0.9791 - recall_m: 0.8648 - val_loss: 0.0256 - val_accuracy: 0.9197 - val_auc_69: 0.9831 - val_f1_m: 0.9123 - val_precision_m: 0.9662 - val_recall_m: 0.8689
# Epoch 5/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0206 - accuracy: 0.9383 - auc_69: 0.9910 - f1_m: 0.9266 - precision_m: 0.9771 - recall_m: 0.8850 - val_loss: 0.0237 - val_accuracy: 0.9237 - val_auc_69: 0.9847 - val_f1_m: 0.9170 - val_precision_m: 0.9715 - val_recall_m: 0.8734
# Epoch 6/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0196 - accuracy: 0.9383 - auc_69: 0.9912 - f1_m: 0.9257 - precision_m: 0.9766 - recall_m: 0.8838 - val_loss: 0.0213 - val_accuracy: 0.9237 - val_auc_69: 0.9880 - val_f1_m: 0.9137 - val_precision_m: 0.9825 - val_recall_m: 0.8597
# Epoch 7/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0175 - accuracy: 0.9497 - auc_69: 0.9931 - f1_m: 0.9457 - precision_m: 0.9868 - recall_m: 0.9109 - val_loss: 0.0199 - val_accuracy: 0.9296 - val_auc_69: 0.9891 - val_f1_m: 0.9238 - val_precision_m: 0.9689 - val_recall_m: 0.8859
# Epoch 8/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0160 - accuracy: 0.9504 - auc_69: 0.9939 - f1_m: 0.9458 - precision_m: 0.9885 - recall_m: 0.9097 - val_loss: 0.0207 - val_accuracy: 0.9267 - val_auc_69: 0.9877 - val_f1_m: 0.9180 - val_precision_m: 0.9675 - val_recall_m: 0.8776
# Epoch 9/10
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0152 - accuracy: 0.9509 - auc_69: 0.9946 - f1_m: 0.9464 - precision_m: 0.9891 - recall_m: 0.9114 - val_loss: 0.0181 - val_accuracy: 0.9296 - val_auc_69: 0.9904 - val_f1_m: 0.9243 - val_precision_m: 0.9788 - val_recall_m: 0.8795
# Epoch 10/10
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0142 - accuracy: 0.9566 - auc_69: 0.9954 - f1_m: 0.9537 - precision_m: 0.9899 - recall_m: 0.9228 - val_loss: 0.0170 - val_accuracy: 0.9465 - val_auc_69: 0.9916 - val_f1_m: 0.9408 - val_precision_m: 0.9806 - val_recall_m: 0.9076
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 2522, 0: 2521})
#
# Validation Data - True -->
# Counter({0: 511, 1: 498})
#
# Validation Data - Prediction -->
# Counter({0: 549, 1: 460})
#
# ------------------------ Test Study: SIM2 ------------------------
# Test Data - True -->
# Counter({1: 724, 0: 656})
#
# Test Data - Prediction -->
# Counter({0: 765, 1: 615})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({1: 290, 0: 260})
#
# Test Data - Prediction -->
# Counter({0: 315, 1: 235})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({0: 5059, 1: 4957})
#
# Test Data - Prediction -->
# Counter({0: 5862, 1: 4154})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 11257, 1: 11077})
#
# Test Data - Prediction -->
# Counter({0: 14269, 1: 8065})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM2 & Modality: PP
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 64/64 [==============================] - 11s 43ms/step - loss: 4.2366 - accuracy: 0.5963 - auc_70: 0.8721 - f1_m: 0.3437 - precision_m: 0.6464 - recall_m: 0.2503 - val_loss: 1.1722 - val_accuracy: 0.7806 - val_auc_70: 0.9799 - val_f1_m: 0.7080 - val_precision_m: 1.0000 - val_recall_m: 0.5581
# Epoch 2/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.4898 - accuracy: 0.8592 - auc_70: 0.9764 - f1_m: 0.8431 - precision_m: 0.9903 - recall_m: 0.7425 - val_loss: 0.1386 - val_accuracy: 0.9526 - val_auc_70: 0.9940 - val_f1_m: 0.9506 - val_precision_m: 0.9877 - val_recall_m: 0.9176
# Epoch 3/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0734 - accuracy: 0.9437 - auc_70: 0.9909 - f1_m: 0.9420 - precision_m: 0.9878 - recall_m: 0.9040 - val_loss: 0.0372 - val_accuracy: 0.9664 - val_auc_70: 0.9952 - val_f1_m: 0.9644 - val_precision_m: 0.9877 - val_recall_m: 0.9436
# Epoch 4/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0299 - accuracy: 0.9550 - auc_70: 0.9928 - f1_m: 0.9519 - precision_m: 0.9844 - recall_m: 0.9250 - val_loss: 0.0231 - val_accuracy: 0.9585 - val_auc_70: 0.9968 - val_f1_m: 0.9572 - val_precision_m: 0.9875 - val_recall_m: 0.9303
# Epoch 5/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0228 - accuracy: 0.9545 - auc_70: 0.9924 - f1_m: 0.9554 - precision_m: 0.9910 - recall_m: 0.9248 - val_loss: 0.0196 - val_accuracy: 0.9585 - val_auc_70: 0.9969 - val_f1_m: 0.9563 - val_precision_m: 0.9877 - val_recall_m: 0.9285
# Epoch 6/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0191 - accuracy: 0.9620 - auc_70: 0.9945 - f1_m: 0.9622 - precision_m: 0.9915 - recall_m: 0.9369 - val_loss: 0.0179 - val_accuracy: 0.9763 - val_auc_70: 0.9979 - val_f1_m: 0.9754 - val_precision_m: 0.9789 - val_recall_m: 0.9733
# Epoch 7/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0175 - accuracy: 0.9639 - auc_70: 0.9955 - f1_m: 0.9642 - precision_m: 0.9892 - recall_m: 0.9423 - val_loss: 0.0157 - val_accuracy: 0.9644 - val_auc_70: 0.9981 - val_f1_m: 0.9635 - val_precision_m: 0.9955 - val_recall_m: 0.9348
# Epoch 8/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0159 - accuracy: 0.9669 - auc_70: 0.9960 - f1_m: 0.9657 - precision_m: 0.9919 - recall_m: 0.9435 - val_loss: 0.0151 - val_accuracy: 0.9664 - val_auc_70: 0.9973 - val_f1_m: 0.9642 - val_precision_m: 0.9914 - val_recall_m: 0.9398
# Epoch 9/10
# 64/64 [==============================] - 1s 9ms/step - loss: 0.0152 - accuracy: 0.9689 - auc_70: 0.9958 - f1_m: 0.9676 - precision_m: 0.9950 - recall_m: 0.9442 - val_loss: 0.0156 - val_accuracy: 0.9644 - val_auc_70: 0.9966 - val_f1_m: 0.9623 - val_precision_m: 0.9877 - val_recall_m: 0.9395
# Epoch 10/10
# 64/64 [==============================] - 1s 10ms/step - loss: 0.0143 - accuracy: 0.9674 - auc_70: 0.9958 - f1_m: 0.9661 - precision_m: 0.9942 - recall_m: 0.9421 - val_loss: 0.0134 - val_accuracy: 0.9704 - val_auc_70: 0.9981 - val_f1_m: 0.9701 - val_precision_m: 0.9880 - val_recall_m: 0.9539
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 1321, 0: 1209})
#
# Validation Data - True -->
# Counter({1: 254, 0: 252})
#
# Validation Data - Prediction -->
# Counter({0: 261, 1: 245})
#
# ------------------------ Test Study: SIM1 ------------------------
# Test Data - True -->
# Counter({1: 4088, 0: 4042})
#
# Test Data - Prediction -->
# Counter({0: 4081, 1: 4049})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({0: 563, 1: 553})
#
# Test Data - Prediction -->
# Counter({1: 604, 0: 512})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 8610, 0: 8354})
#
# Test Data - Prediction -->
# Counter({1: 9479, 0: 7485})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15116, 0: 14682})
#
# Test Data - Prediction -->
# Counter({0: 16473, 1: 13325})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM2 & Modality: HR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 63/63 [==============================] - 11s 46ms/step - loss: 4.2674 - accuracy: 0.6567 - auc_71: 0.8533 - f1_m: 0.4603 - precision_m: 0.7579 - recall_m: 0.3609 - val_loss: 1.2136 - val_accuracy: 0.8044 - val_auc_71: 0.9436 - val_f1_m: 0.7490 - val_precision_m: 0.9650 - val_recall_m: 0.6224
# Epoch 2/10
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5149 - accuracy: 0.8296 - auc_71: 0.9475 - f1_m: 0.7998 - precision_m: 0.9629 - recall_m: 0.6941 - val_loss: 0.1575 - val_accuracy: 0.8463 - val_auc_71: 0.9656 - val_f1_m: 0.8130 - val_precision_m: 0.9804 - val_recall_m: 0.7002
# Epoch 3/10
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0863 - accuracy: 0.8701 - auc_71: 0.9669 - f1_m: 0.8544 - precision_m: 0.9679 - recall_m: 0.7725 - val_loss: 0.0489 - val_accuracy: 0.9122 - val_auc_71: 0.9733 - val_f1_m: 0.8979 - val_precision_m: 0.9636 - val_recall_m: 0.8498
# Epoch 4/10
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0406 - accuracy: 0.8871 - auc_71: 0.9740 - f1_m: 0.8800 - precision_m: 0.9737 - recall_m: 0.8089 - val_loss: 0.0342 - val_accuracy: 0.8922 - val_auc_71: 0.9750 - val_f1_m: 0.8686 - val_precision_m: 0.9794 - val_recall_m: 0.7887
# Epoch 5/10
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0320 - accuracy: 0.8976 - auc_71: 0.9782 - f1_m: 0.8893 - precision_m: 0.9799 - recall_m: 0.8206 - val_loss: 0.0294 - val_accuracy: 0.9341 - val_auc_71: 0.9794 - val_f1_m: 0.9240 - val_precision_m: 0.9712 - val_recall_m: 0.8872
# Epoch 6/10
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0287 - accuracy: 0.9065 - auc_71: 0.9806 - f1_m: 0.8974 - precision_m: 0.9751 - recall_m: 0.8357 - val_loss: 0.0262 - val_accuracy: 0.9381 - val_auc_71: 0.9803 - val_f1_m: 0.9289 - val_precision_m: 0.9838 - val_recall_m: 0.8864
# Epoch 7/10
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0272 - accuracy: 0.9075 - auc_71: 0.9812 - f1_m: 0.8977 - precision_m: 0.9761 - recall_m: 0.8386 - val_loss: 0.0266 - val_accuracy: 0.9202 - val_auc_71: 0.9785 - val_f1_m: 0.9053 - val_precision_m: 0.9748 - val_recall_m: 0.8510
# Epoch 8/10
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0262 - accuracy: 0.9170 - auc_71: 0.9823 - f1_m: 0.9156 - precision_m: 0.9750 - recall_m: 0.8679 - val_loss: 0.0254 - val_accuracy: 0.9242 - val_auc_71: 0.9799 - val_f1_m: 0.9080 - val_precision_m: 0.9931 - val_recall_m: 0.8433
# Epoch 9/10
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0251 - accuracy: 0.9085 - auc_71: 0.9832 - f1_m: 0.9015 - precision_m: 0.9808 - recall_m: 0.8407 - val_loss: 0.0238 - val_accuracy: 0.9361 - val_auc_71: 0.9819 - val_f1_m: 0.9234 - val_precision_m: 0.9789 - val_recall_m: 0.8790
# Epoch 10/10
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0239 - accuracy: 0.9195 - auc_71: 0.9841 - f1_m: 0.9135 - precision_m: 0.9787 - recall_m: 0.8618 - val_loss: 0.0222 - val_accuracy: 0.9381 - val_auc_71: 0.9842 - val_f1_m: 0.9246 - val_precision_m: 0.9793 - val_recall_m: 0.8814
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 1279, 0: 1223})
#
# Validation Data - True -->
# Counter({0: 256, 1: 245})
#
# Validation Data - Prediction -->
# Counter({0: 279, 1: 222})
#
# ------------------------ Test Study: SIM1 ------------------------
# Test Data - True -->
# Counter({1: 4097, 0: 4076})
#
# Test Data - Prediction -->
# Counter({0: 4247, 1: 3926})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({0: 581, 1: 566})
#
# Test Data - Prediction -->
# Counter({0: 708, 1: 439})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 8488, 0: 8428})
#
# Test Data - Prediction -->
# Counter({0: 10241, 1: 6675})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15089, 0: 14688})
#
# Test Data - Prediction -->
# Counter({0: 18540, 1: 11237})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM2 & Modality: BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 64/64 [==============================] - 13s 54ms/step - loss: 4.2240 - accuracy: 0.7421 - auc_72: 0.9289 - f1_m: 0.5773 - precision_m: 0.7676 - recall_m: 0.4958 - val_loss: 1.1620 - val_accuracy: 0.8757 - val_auc_72: 0.9818 - val_f1_m: 0.8464 - val_precision_m: 0.9886 - val_recall_m: 0.7451
# Epoch 2/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.4794 - accuracy: 0.9137 - auc_72: 0.9873 - f1_m: 0.9062 - precision_m: 0.9868 - recall_m: 0.8441 - val_loss: 0.1369 - val_accuracy: 0.9270 - val_auc_72: 0.9896 - val_f1_m: 0.9203 - val_precision_m: 0.9790 - val_recall_m: 0.8720
# Epoch 3/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0691 - accuracy: 0.9443 - auc_72: 0.9926 - f1_m: 0.9395 - precision_m: 0.9886 - recall_m: 0.8996 - val_loss: 0.0386 - val_accuracy: 0.9172 - val_auc_72: 0.9892 - val_f1_m: 0.9066 - val_precision_m: 0.9845 - val_recall_m: 0.8444
# Epoch 4/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0264 - accuracy: 0.9512 - auc_72: 0.9962 - f1_m: 0.9467 - precision_m: 0.9914 - recall_m: 0.9092 - val_loss: 0.0238 - val_accuracy: 0.9290 - val_auc_72: 0.9925 - val_f1_m: 0.9208 - val_precision_m: 0.9874 - val_recall_m: 0.8665
# Epoch 5/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0195 - accuracy: 0.9615 - auc_72: 0.9964 - f1_m: 0.9602 - precision_m: 0.9904 - recall_m: 0.9341 - val_loss: 0.0199 - val_accuracy: 0.9527 - val_auc_72: 0.9943 - val_f1_m: 0.9505 - val_precision_m: 0.9847 - val_recall_m: 0.9204
# Epoch 6/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0164 - accuracy: 0.9675 - auc_72: 0.9974 - f1_m: 0.9659 - precision_m: 0.9929 - recall_m: 0.9424 - val_loss: 0.0185 - val_accuracy: 0.9448 - val_auc_72: 0.9948 - val_f1_m: 0.9411 - val_precision_m: 0.9963 - val_recall_m: 0.8943
# Epoch 7/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0146 - accuracy: 0.9650 - auc_72: 0.9980 - f1_m: 0.9633 - precision_m: 0.9934 - recall_m: 0.9373 - val_loss: 0.0181 - val_accuracy: 0.9369 - val_auc_72: 0.9939 - val_f1_m: 0.9314 - val_precision_m: 0.9884 - val_recall_m: 0.8834
# Epoch 8/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0133 - accuracy: 0.9729 - auc_72: 0.9980 - f1_m: 0.9701 - precision_m: 0.9946 - recall_m: 0.9494 - val_loss: 0.0159 - val_accuracy: 0.9527 - val_auc_72: 0.9957 - val_f1_m: 0.9518 - val_precision_m: 0.9855 - val_recall_m: 0.9227
# Epoch 9/10
# 64/64 [==============================] - 1s 11ms/step - loss: 0.0125 - accuracy: 0.9699 - auc_72: 0.9983 - f1_m: 0.9688 - precision_m: 0.9944 - recall_m: 0.9470 - val_loss: 0.0141 - val_accuracy: 0.9527 - val_auc_72: 0.9963 - val_f1_m: 0.9501 - val_precision_m: 0.9932 - val_recall_m: 0.9129
# Epoch 10/10
# 64/64 [==============================] - 1s 10ms/step - loss: 0.0114 - accuracy: 0.9729 - auc_72: 0.9985 - f1_m: 0.9711 - precision_m: 0.9954 - recall_m: 0.9496 - val_loss: 0.0138 - val_accuracy: 0.9546 - val_auc_72: 0.9964 - val_f1_m: 0.9527 - val_precision_m: 0.9893 - val_recall_m: 0.9209
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 1274, 0: 1261})
#
# Validation Data - True -->
# Counter({0: 265, 1: 242})
#
# Validation Data - Prediction -->
# Counter({0: 282, 1: 225})
#
# ------------------------ Test Study: SIM1 ------------------------
# Test Data - True -->
# Counter({1: 4191, 0: 3924})
#
# Test Data - Prediction -->
# Counter({0: 4528, 1: 3587})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({1: 604, 0: 520})
#
# Test Data - Prediction -->
# Counter({1: 562, 0: 562})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 8624, 0: 8295})
#
# Test Data - Prediction -->
# Counter({0: 8983, 1: 7936})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15089, 0: 14688})
#
# Test Data - Prediction -->
# Counter({0: 17568, 1: 12209})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM2 & Modality: PP_HR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 44/44 [==============================] - 11s 64ms/step - loss: 5.3327 - accuracy: 0.5582 - auc_73: 0.8153 - f1_m: 0.2118 - precision_m: 0.4818 - recall_m: 0.1457 - val_loss: 2.3309 - val_accuracy: 0.6827 - val_auc_73: 0.9443 - val_f1_m: 0.5050 - val_precision_m: 0.9074 - val_recall_m: 0.3563
# Epoch 2/10
# 44/44 [==============================] - 0s 9ms/step - loss: 1.2220 - accuracy: 0.7592 - auc_73: 0.9609 - f1_m: 0.6816 - precision_m: 0.9578 - recall_m: 0.5564 - val_loss: 0.5094 - val_accuracy: 0.8839 - val_auc_73: 0.9862 - val_f1_m: 0.7974 - val_precision_m: 0.9115 - val_recall_m: 0.7136
# Epoch 3/10
# 44/44 [==============================] - 0s 9ms/step - loss: 0.2731 - accuracy: 0.8942 - auc_73: 0.9828 - f1_m: 0.8814 - precision_m: 0.9754 - recall_m: 0.8119 - val_loss: 0.1233 - val_accuracy: 0.9575 - val_auc_73: 0.9935 - val_f1_m: 0.9599 - val_precision_m: 0.9772 - val_recall_m: 0.9436
# Epoch 4/10
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0767 - accuracy: 0.9361 - auc_73: 0.9899 - f1_m: 0.9326 - precision_m: 0.9790 - recall_m: 0.8942 - val_loss: 0.0470 - val_accuracy: 0.9660 - val_auc_73: 0.9950 - val_f1_m: 0.9684 - val_precision_m: 0.9777 - val_recall_m: 0.9605
# Epoch 5/10
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0363 - accuracy: 0.9510 - auc_73: 0.9935 - f1_m: 0.9506 - precision_m: 0.9877 - recall_m: 0.9194 - val_loss: 0.0265 - val_accuracy: 0.9717 - val_auc_73: 0.9975 - val_f1_m: 0.9750 - val_precision_m: 0.9951 - val_recall_m: 0.9571
# Epoch 6/10
# 44/44 [==============================] - 0s 9ms/step - loss: 0.0255 - accuracy: 0.9517 - auc_73: 0.9949 - f1_m: 0.9493 - precision_m: 0.9860 - recall_m: 0.9186 - val_loss: 0.0210 - val_accuracy: 0.9717 - val_auc_73: 0.9977 - val_f1_m: 0.9746 - val_precision_m: 1.0000 - val_recall_m: 0.9516
# Epoch 7/10
# 44/44 [==============================] - 0s 9ms/step - loss: 0.0208 - accuracy: 0.9616 - auc_73: 0.9963 - f1_m: 0.9586 - precision_m: 0.9838 - recall_m: 0.9371 - val_loss: 0.0177 - val_accuracy: 0.9745 - val_auc_73: 0.9987 - val_f1_m: 0.9777 - val_precision_m: 1.0000 - val_recall_m: 0.9575
# Epoch 8/10
# 44/44 [==============================] - 0s 9ms/step - loss: 0.0193 - accuracy: 0.9631 - auc_73: 0.9961 - f1_m: 0.9636 - precision_m: 0.9895 - recall_m: 0.9410 - val_loss: 0.0165 - val_accuracy: 0.9603 - val_auc_73: 0.9993 - val_f1_m: 0.9637 - val_precision_m: 1.0000 - val_recall_m: 0.9312
# Epoch 9/10
# 44/44 [==============================] - 0s 9ms/step - loss: 0.0171 - accuracy: 0.9624 - auc_73: 0.9972 - f1_m: 0.9607 - precision_m: 0.9906 - recall_m: 0.9348 - val_loss: 0.0149 - val_accuracy: 0.9773 - val_auc_73: 0.9990 - val_f1_m: 0.9802 - val_precision_m: 1.0000 - val_recall_m: 0.9620
# Epoch 10/10
# 44/44 [==============================] - 0s 9ms/step - loss: 0.0157 - accuracy: 0.9723 - auc_73: 0.9980 - f1_m: 0.9724 - precision_m: 0.9922 - recall_m: 0.9554 - val_loss: 0.0141 - val_accuracy: 0.9717 - val_auc_73: 0.9994 - val_f1_m: 0.9746 - val_precision_m: 1.0000 - val_recall_m: 0.9520
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 900, 0: 861})
#
# Validation Data - True -->
# Counter({1: 180, 0: 173})
#
# Validation Data - Prediction -->
# Counter({0: 183, 1: 170})
#
# ------------------------ Test Study: SIM1 ------------------------
# Test Data - True -->
# Counter({1: 3123, 0: 3080})
#
# Test Data - Prediction -->
# Counter({1: 3219, 0: 2984})
#
# ------------------------ Test Study: TT1 ------------------------
# Test Data - True -->
# Counter({0: 404, 1: 403})
#
# Test Data - Prediction -->
# Counter({0: 492, 1: 315})
#
# ------------------------ Test Study: OFFICE_TASKS ------------------------
# Test Data - True -->
# Counter({1: 6562, 0: 6141})
#
# Test Data - Prediction -->
# Counter({0: 7001, 1: 5702})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 10746, 1: 10642})
#
# Test Data - Prediction -->
# Counter({0: 13017, 1: 8371})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM2 & Modality: HR_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 49/49 [==============================] - 11s 54ms/step - loss: 4.9992 - accuracy: 0.7261 - auc_74: 0.8955 - f1_m: 0.6069 - precision_m: 0.8448 - recall_m: 0.5245 - val_loss: 1.9471 - val_accuracy: 0.9005 - val_auc_74: 0.9839 - val_f1_m: 0.8804 - val_precision_m: 1.0000 - val_recall_m: 0.7882
# Epoch 2/10
# 49/49 [==============================] - 1s 11ms/step - loss: 0.9520 - accuracy: 0.9234 - auc_74: 0.9897 - f1_m: 0.9193 - precision_m: 0.9946 - recall_m: 0.8586 - val_loss: 0.3540 - val_accuracy: 0.9464 - val_auc_74: 0.9933 - val_f1_m: 0.9361 - val_precision_m: 0.9957 - val_recall_m: 0.8854
# Epoch 3/10
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1797 - accuracy: 0.9489 - auc_74: 0.9954 - f1_m: 0.9447 - precision_m: 0.9924 - recall_m: 0.9050 - val_loss: 0.0785 - val_accuracy: 0.9515 - val_auc_74: 0.9954 - val_f1_m: 0.9408 - val_precision_m: 0.9872 - val_recall_m: 0.9000
# Epoch 4/10
# ...
# Epoch 8/10
# 537/537 [==============================] - 4s 8ms/step - loss: 0.0155 - accuracy: 0.9392 - auc_122: 0.9910 - f1_m: 0.9351 - precision_m: 0.9835 - recall_m: 0.8953 - val_loss: 0.0180 - val_accuracy: 0.9388 - val_auc_122: 0.9868 - val_f1_m: 0.9386 - val_precision_m: 0.9833 - val_recall_m: 0.9006
# Epoch 9/10
# 537/537 [==============================] - 4s 8ms/step - loss: 0.0148 - accuracy: 0.9415 - auc_122: 0.9921 - f1_m: 0.9380 - precision_m: 0.9845 - recall_m: 0.8998 - val_loss: 0.0179 - val_accuracy: 0.9506 - val_auc_122: 0.9889 - val_f1_m: 0.9518 - val_precision_m: 0.9791 - val_recall_m: 0.9286
# Epoch 10/10
# 537/537 [==============================] - 4s 8ms/step - loss: 0.0144 - accuracy: 0.9438 - auc_122: 0.9925 - f1_m: 0.9411 - precision_m: 0.9842 - recall_m: 0.9053 - val_loss: 0.0152 - val_accuracy: 0.9523 - val_auc_122: 0.9915 - val_f1_m: 0.9525 - val_precision_m: 0.9849 - val_recall_m: 0.9249
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 10988, 0: 10486})
#
# Validation Data - True -->
# Counter({1: 2227, 0: 2068})
#
# Validation Data - Prediction -->
# Counter({0: 2207, 1: 2088})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 10746, 1: 10642})
#
# Test Data - Prediction -->
# Counter({0: 12973, 1: 8415})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1___SIM2___TT1___OFFICE_TASKS & Modality: HR_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 517/517 [==============================] - 11s 10ms/step - loss: 0.6156 - accuracy: 0.8182 - auc_123: 0.9449 - f1_m: 0.7704 - precision_m: 0.9368 - recall_m: 0.6728 - val_loss: 0.0341 - val_accuracy: 0.8424 - val_auc_123: 0.9674 - val_f1_m: 0.8143 - val_precision_m: 0.9823 - val_recall_m: 0.7037
# Epoch 2/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0258 - accuracy: 0.9014 - auc_123: 0.9803 - f1_m: 0.8913 - precision_m: 0.9764 - recall_m: 0.8264 - val_loss: 0.0232 - val_accuracy: 0.9066 - val_auc_123: 0.9839 - val_f1_m: 0.8991 - val_precision_m: 0.9814 - val_recall_m: 0.8338
# Epoch 3/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0207 - accuracy: 0.9241 - auc_123: 0.9870 - f1_m: 0.9178 - precision_m: 0.9783 - recall_m: 0.8698 - val_loss: 0.0219 - val_accuracy: 0.9250 - val_auc_123: 0.9829 - val_f1_m: 0.9187 - val_precision_m: 0.9794 - val_recall_m: 0.8695
# Epoch 4/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0185 - accuracy: 0.9323 - auc_123: 0.9887 - f1_m: 0.9281 - precision_m: 0.9812 - recall_m: 0.8850 - val_loss: 0.0177 - val_accuracy: 0.9397 - val_auc_123: 0.9898 - val_f1_m: 0.9365 - val_precision_m: 0.9812 - val_recall_m: 0.9000
# Epoch 5/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0166 - accuracy: 0.9395 - auc_123: 0.9909 - f1_m: 0.9356 - precision_m: 0.9832 - recall_m: 0.8963 - val_loss: 0.0189 - val_accuracy: 0.9100 - val_auc_123: 0.9888 - val_f1_m: 0.9027 - val_precision_m: 0.9871 - val_recall_m: 0.8370
# Epoch 6/10
# 517/517 [==============================] - 4s 8ms/step - loss: 0.0161 - accuracy: 0.9392 - auc_123: 0.9912 - f1_m: 0.9354 - precision_m: 0.9826 - recall_m: 0.8963 - val_loss: 0.0181 - val_accuracy: 0.9390 - val_auc_123: 0.9891 - val_f1_m: 0.9350 - val_precision_m: 0.9695 - val_recall_m: 0.9075
# Epoch 7/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0147 - accuracy: 0.9435 - auc_123: 0.9926 - f1_m: 0.9404 - precision_m: 0.9841 - recall_m: 0.9042 - val_loss: 0.0151 - val_accuracy: 0.9482 - val_auc_123: 0.9919 - val_f1_m: 0.9472 - val_precision_m: 0.9825 - val_recall_m: 0.9171
# Epoch 8/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0143 - accuracy: 0.9467 - auc_123: 0.9929 - f1_m: 0.9436 - precision_m: 0.9843 - recall_m: 0.9095 - val_loss: 0.0145 - val_accuracy: 0.9470 - val_auc_123: 0.9930 - val_f1_m: 0.9443 - val_precision_m: 0.9866 - val_recall_m: 0.9090
# Epoch 9/10
# 517/517 [==============================] - 4s 8ms/step - loss: 0.0141 - accuracy: 0.9481 - auc_123: 0.9933 - f1_m: 0.9452 - precision_m: 0.9850 - recall_m: 0.9124 - val_loss: 0.0145 - val_accuracy: 0.9530 - val_auc_123: 0.9925 - val_f1_m: 0.9520 - val_precision_m: 0.9852 - val_recall_m: 0.9238
# Epoch 10/10
# 517/517 [==============================] - 4s 7ms/step - loss: 0.0139 - accuracy: 0.9470 - auc_123: 0.9934 - f1_m: 0.9436 - precision_m: 0.9854 - recall_m: 0.9091 - val_loss: 0.0153 - val_accuracy: 0.9499 - val_auc_123: 0.9921 - val_f1_m: 0.9471 - val_precision_m: 0.9793 - val_recall_m: 0.9208
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 10542, 0: 10115})
#
# Validation Data - True -->
# Counter({1: 2125, 0: 2007})
#
# Validation Data - Prediction -->
# Counter({0: 2130, 1: 2002})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({1: 15089, 0: 14688})
#
# Test Data - Prediction -->
# Counter({0: 19926, 1: 9851})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1___SIM2___TT1___OFFICE_TASKS & Modality: PP_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 475/475 [==============================] - 11s 10ms/step - loss: 0.6607 - accuracy: 0.8630 - auc_124: 0.9655 - f1_m: 0.8393 - precision_m: 0.9621 - recall_m: 0.7634 - val_loss: 0.0269 - val_accuracy: 0.9170 - val_auc_124: 0.9789 - val_f1_m: 0.9091 - val_precision_m: 0.9778 - val_recall_m: 0.8547
# Epoch 2/10
# 475/475 [==============================] - 3s 7ms/step - loss: 0.0219 - accuracy: 0.9289 - auc_124: 0.9871 - f1_m: 0.9257 - precision_m: 0.9805 - recall_m: 0.8812 - val_loss: 0.0199 - val_accuracy: 0.9297 - val_auc_124: 0.9879 - val_f1_m: 0.9235 - val_precision_m: 0.9839 - val_recall_m: 0.8746
# Epoch 3/10
# 475/475 [==============================] - 3s 7ms/step - loss: 0.0173 - accuracy: 0.9413 - auc_124: 0.9916 - f1_m: 0.9396 - precision_m: 0.9853 - recall_m: 0.9013 - val_loss: 0.0170 - val_accuracy: 0.9434 - val_auc_124: 0.9905 - val_f1_m: 0.9386 - val_precision_m: 0.9857 - val_recall_m: 0.9001
# Epoch 4/10
# 475/475 [==============================] - 3s 7ms/step - loss: 0.0146 - accuracy: 0.9507 - auc_124: 0.9939 - f1_m: 0.9499 - precision_m: 0.9854 - recall_m: 0.9198 - val_loss: 0.0158 - val_accuracy: 0.9352 - val_auc_124: 0.9926 - val_f1_m: 0.9295 - val_precision_m: 0.9916 - val_recall_m: 0.8781
# Epoch 5/10
# 475/475 [==============================] - 3s 7ms/step - loss: 0.0127 - accuracy: 0.9592 - auc_124: 0.9953 - f1_m: 0.9587 - precision_m: 0.9893 - recall_m: 0.9327 - val_loss: 0.0139 - val_accuracy: 0.9434 - val_auc_124: 0.9936 - val_f1_m: 0.9388 - val_precision_m: 0.9917 - val_recall_m: 0.8945
# Epoch 6/10
# 475/475 [==============================] - 4s 7ms/step - loss: 0.0116 - accuracy: 0.9609 - auc_124: 0.9960 - f1_m: 0.9607 - precision_m: 0.9912 - recall_m: 0.9345 - val_loss: 0.0150 - val_accuracy: 0.9634 - val_auc_124: 0.9936 - val_f1_m: 0.9622 - val_precision_m: 0.9753 - val_recall_m: 0.9519
# Epoch 7/10
# 475/475 [==============================] - 4s 7ms/step - loss: 0.0112 - accuracy: 0.9634 - auc_124: 0.9961 - f1_m: 0.9629 - precision_m: 0.9892 - recall_m: 0.9405 - val_loss: 0.0121 - val_accuracy: 0.9644 - val_auc_124: 0.9957 - val_f1_m: 0.9621 - val_precision_m: 0.9874 - val_recall_m: 0.9401
# Epoch 8/10
# 475/475 [==============================] - 4s 8ms/step - loss: 0.0110 - accuracy: 0.9642 - auc_124: 0.9964 - f1_m: 0.9638 - precision_m: 0.9905 - recall_m: 0.9410 - val_loss: 0.0123 - val_accuracy: 0.9666 - val_auc_124: 0.9946 - val_f1_m: 0.9656 - val_precision_m: 0.9829 - val_recall_m: 0.9507
# Epoch 9/10
# 475/475 [==============================] - 4s 8ms/step - loss: 0.0103 - accuracy: 0.9669 - auc_124: 0.9967 - f1_m: 0.9665 - precision_m: 0.9914 - recall_m: 0.9453 - val_loss: 0.0108 - val_accuracy: 0.9708 - val_auc_124: 0.9965 - val_f1_m: 0.9694 - val_precision_m: 0.9877 - val_recall_m: 0.9535
# Epoch 10/10
# 475/475 [==============================] - 4s 8ms/step - loss: 0.0095 - accuracy: 0.9706 - auc_124: 0.9973 - f1_m: 0.9706 - precision_m: 0.9933 - recall_m: 0.9510 - val_loss: 0.0101 - val_accuracy: 0.9734 - val_auc_124: 0.9968 - val_f1_m: 0.9722 - val_precision_m: 0.9886 - val_recall_m: 0.9580
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({1: 9858, 0: 9125})
#
# Validation Data - True -->
# Counter({1: 1907, 0: 1890})
#
# Validation Data - Prediction -->
# Counter({0: 1947, 1: 1850})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 10746, 1: 10642})
#
# Test Data - Prediction -->
# Counter({0: 11452, 1: 9936})
# ----------------------------------------------------
# ----------------------------------------------------
# Train Studies:  SIM1___SIM2___TT1___OFFICE_TASKS & Modality: PP_HR_BR
# ----------------------------------------------------
# ----------------------------------------------------
#
# Epoch 1/10
# 425/425 [==============================] - 11s 11ms/step - loss: 0.7379 - accuracy: 0.8305 - auc_125: 0.9489 - f1_m: 0.7726 - precision_m: 0.9247 - recall_m: 0.6855 - val_loss: 0.0274 - val_accuracy: 0.9155 - val_auc_125: 0.9812 - val_f1_m: 0.9076 - val_precision_m: 0.9722 - val_recall_m: 0.8561
# Epoch 2/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0230 - accuracy: 0.9172 - auc_125: 0.9860 - f1_m: 0.9076 - precision_m: 0.9811 - recall_m: 0.8504 - val_loss: 0.0202 - val_accuracy: 0.9420 - val_auc_125: 0.9901 - val_f1_m: 0.9396 - val_precision_m: 0.9736 - val_recall_m: 0.9117
# Epoch 3/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0176 - accuracy: 0.9412 - auc_125: 0.9918 - f1_m: 0.9362 - precision_m: 0.9840 - recall_m: 0.8969 - val_loss: 0.0168 - val_accuracy: 0.9420 - val_auc_125: 0.9926 - val_f1_m: 0.9372 - val_precision_m: 0.9831 - val_recall_m: 0.8999
# Epoch 4/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0150 - accuracy: 0.9506 - auc_125: 0.9940 - f1_m: 0.9469 - precision_m: 0.9881 - recall_m: 0.9125 - val_loss: 0.0139 - val_accuracy: 0.9585 - val_auc_125: 0.9951 - val_f1_m: 0.9565 - val_precision_m: 0.9858 - val_recall_m: 0.9314
# Epoch 5/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0132 - accuracy: 0.9570 - auc_125: 0.9953 - f1_m: 0.9543 - precision_m: 0.9873 - recall_m: 0.9263 - val_loss: 0.0150 - val_accuracy: 0.9603 - val_auc_125: 0.9941 - val_f1_m: 0.9587 - val_precision_m: 0.9700 - val_recall_m: 0.9502
# Epoch 6/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0126 - accuracy: 0.9608 - auc_125: 0.9956 - f1_m: 0.9579 - precision_m: 0.9888 - recall_m: 0.9320 - val_loss: 0.0116 - val_accuracy: 0.9679 - val_auc_125: 0.9967 - val_f1_m: 0.9666 - val_precision_m: 0.9811 - val_recall_m: 0.9542
# Epoch 7/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0115 - accuracy: 0.9612 - auc_125: 0.9964 - f1_m: 0.9581 - precision_m: 0.9881 - recall_m: 0.9327 - val_loss: 0.0099 - val_accuracy: 0.9741 - val_auc_125: 0.9977 - val_f1_m: 0.9728 - val_precision_m: 0.9886 - val_recall_m: 0.9591
# Epoch 8/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0110 - accuracy: 0.9650 - auc_125: 0.9967 - f1_m: 0.9633 - precision_m: 0.9892 - recall_m: 0.9411 - val_loss: 0.0109 - val_accuracy: 0.9597 - val_auc_125: 0.9967 - val_f1_m: 0.9563 - val_precision_m: 0.9892 - val_recall_m: 0.9280
# Epoch 9/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0103 - accuracy: 0.9659 - auc_125: 0.9970 - f1_m: 0.9636 - precision_m: 0.9894 - recall_m: 0.9417 - val_loss: 0.0106 - val_accuracy: 0.9700 - val_auc_125: 0.9971 - val_f1_m: 0.9692 - val_precision_m: 0.9861 - val_recall_m: 0.9544
# Epoch 10/10
# 425/425 [==============================] - 3s 7ms/step - loss: 0.0099 - accuracy: 0.9681 - auc_125: 0.9972 - f1_m: 0.9666 - precision_m: 0.9895 - recall_m: 0.9471 - val_loss: 0.0094 - val_accuracy: 0.9617 - val_auc_125: 0.9979 - val_f1_m: 0.9596 - val_precision_m: 0.9910 - val_recall_m: 0.9326
#
# ------------------------ Train Study ------------------------
# Train Data - True -->
# Counter({0: 8496, 1: 8493})
#
# Validation Data - True -->
# Counter({1: 1711, 0: 1687})
#
# Validation Data - Prediction -->
# Counter({0: 1789, 1: 1609})
#
# ------------------------ Test Study: DEADLINE_STUDY ------------------------
# Test Data - True -->
# Counter({0: 11257, 1: 11077})
#
# Test Data - Prediction -->
# Counter({0: 15568, 1: 6766})
#     Model Arousal_Signal                       Train_Study      Test_Study  \
# 0    LSTM             PP                              sim1            sim2
# 1    LSTM             PP                              sim1             tt1
# 2    LSTM             PP                              sim1    office_tasks
# 3    LSTM             PP                              sim1  deadline_study
# 4    LSTM             HR                              sim1            sim2
# ..    ...            ...                               ...             ...
# 247  LSTM             BR  sim1___sim2___tt1___office_tasks  deadline_study
# 248  LSTM          PP_HR  sim1___sim2___tt1___office_tasks  deadline_study
# 249  LSTM          HR_BR  sim1___sim2___tt1___office_tasks  deadline_study
# 250  LSTM          PP_BR  sim1___sim2___tt1___office_tasks  deadline_study
# 251  LSTM       PP_HR_BR  sim1___sim2___tt1___office_tasks  deadline_study
#
#      Train_Accuracy  Test_Accuracy  Train_AUC  Test_AUC  Train_F1  Test_F1  \
# 0              0.94           0.61       0.99      0.63      0.94     0.61
# 1              0.94           0.72       0.99      0.82      0.94     0.71
# 2              0.94           0.63       0.99      0.72      0.94     0.63
# 3              0.94           0.64       0.99      0.70      0.94     0.64
# 4              0.82           0.56       0.94      0.52      0.82     0.55
# ..              ...            ...        ...       ...       ...      ...
# 247            0.92           0.70       0.99      0.76      0.92     0.69
# 248            0.95           0.82       0.99      0.88      0.95     0.81
# 249            0.95           0.68       0.99      0.70      0.95     0.67
# 250            0.97           0.72       1.00      0.86      0.97     0.72
# 251            0.96           0.77       1.00      0.86      0.96     0.76
#
#      Train_Recall  Test_Recall  Train_Precision  Test_Precision  \
# 0            0.94         0.61             0.94            0.61
# 1            0.94         0.72             0.94            0.72
# 2            0.94         0.63             0.94            0.63
# 3            0.94         0.64             0.94            0.64
# 4            0.82         0.56             0.85            0.57
# ..            ...          ...              ...             ...
# 247          0.92         0.70             0.92            0.72
# 248          0.95         0.82             0.95            0.83
# 249          0.95         0.68             0.95            0.71
# 250          0.97         0.72             0.97            0.72
# 251          0.96         0.77             0.96            0.82
#
#      Train_Specificity  Test_Specificity
# 0                 0.97              0.63
# 1                 0.97              0.81
# 2                 0.97              0.65
# 3                 0.97              0.58
# 4                 0.95              0.71
# ..                 ...               ...
# 247               0.99              0.84
# 248               0.98              0.92
# 249               0.98              0.86
# 250               0.99              0.75
# 251               0.99              0.96
#
# [252 rows x 16 columns]

# %%
# loss: 0.0208 - accuracy: 0.9001 - f1_m: 0.8761 - precision_m: 0.9773 - recall_m: 0.8009
# val_loss: 0.0325 - val_accuracy: 0.8527 - val_f1_m: 0.8304 - vals_precision_m: 0.9588 - val_recall_m: 0.7407

# %%
modeling_time = end_time - start_time
print("--- Total Time %s mins (%s hours) ---" % (modeling_time//60, modeling_time//3600))
# Out:
# --- Total Time 54.0 mins (0.0 hours) ---

# %%
# root_path = add_path(all_studies_data_dir, metrics_dir) 
# files = ['metrics_lstm_v0.csv', 'metrics_lstm_v1.csv']
# final_file_name = 'metrics_lstm_all.csv'

# concat_df(root_path, files, final_file_name)

# %%
# start_time = time.time()

# for study_combination in study_combinations_to_run:
    
#     train_studies = study_combinations[study_combination]['Train']
#     test_studies = study_combinations[study_combination]['Test']
#     # print(train_studies, test_studies, study_combination)
    
#     train_df = all_studies_df.copy()[all_studies_df.Study_Name.isin(train_studies)]
#     # print(all_studies_df.shape, train_df.shape)
    
#     model_metrics = {}

    
#     for arousal_signal in arousal_signals:
        
#         train_df = all_studies_df.copy()[all_studies_df.Study_Name.isin(train_studies)]
#         if ground_truth_method == 'ecdf': 
#             train_df = train_df[train_df[arousal_signal+'_Arousal_Mode_Cat'] != -1]
        
#         try:
#             print(decorator + '\n' + decorator)
#             print('Train Studies: ', study_combination.upper() + ' & Modality: ' + arousal_signal)
#             print(decorator + '\n' + decorator + '\n')


#             # Ref: https://stackoverflow.com/questions/3975376/understanding-dict-copy-shallow-or-deep
#             model_metrics[arousal_signal] = {
#                 'K_Fold': copy.deepcopy(all_metrics),
#                 'Train': copy.deepcopy(all_metrics),
#                 'Test': {}
#             }

#             # print(train_df[arousal_signal+'_Arousal_Mode_Cat'].unique())
#             # print(train_df.shape)
            
#             model = get_trained_dnn_model(train_df, arousal_signal)


#             # for i, test_study in enumerate(test_studies):
#             for j in range(1, len(test_studies)+1):
#                 for subset in itertools.combinations(test_studies, j):
              
#                     test_study_subset = list(subset)
#                     test_study_str = '___'.join(test_study_subset).upper()
#                     # print('\n------------------------ Test Study' + str(i+1) + ': ' + test_study.upper() + ' ------------------------')
#                     print('\n------------------------ Test Study: ' + test_study_str + ' ------------------------')
 
#                     model_metrics[arousal_signal]['Test'][test_study_str] = copy.deepcopy(all_metrics)
#                     test_df = all_studies_df.copy()[all_studies_df.Study_Name.isin(test_study_subset)]
#                     if ground_truth_method == 'ecdf': 
#                         test_df = test_df[test_df[arousal_signal+'_Arousal_Mode_Cat'] != -1]
#                     test_dnn_model(model, test_study_str, test_df, arousal_signal)

#                     metrics_df = metrics_df.append(get_test_study_metrics_df(arousal_signal, study_combination, test_study_str, model_metrics, k_fold=run_k_fold), ignore_index = True)

#             if not test_studies: metrics_df = metrics_df.append(get_test_study_metrics_df(arousal_signal, study_combination, None, model_metrics), ignore_index = True)
    
#         except Exception as e:
#             print("An exception occurred for %s %s --> %s" % (study_combination, arousal_signal, e))
    
#     # pprint.pprint(model_metrics)
#     # overleaf_final_tables[study_combination] = get_overleaf_table(study_combination, model_metrics)
#     study_combination_model_metrics[study_combination] = model_metrics
    
    
# display(metrics_df)
# metrics_df.to_csv(add_path(all_studies_data_dir, metrics_dir) + 'lstm_' + dnn_window_size + '_' + get_date_time() + '.csv', sep=',', index=False)


# end_time = time.time()
